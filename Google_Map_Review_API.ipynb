# %%
from serpapi import GoogleSearch
from urllib.parse import urlsplit, parse_qsl
import os, json
from collections import defaultdict
import numpy as np

# %%
Key = "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"

# %%
params = {
    # https://docs.python.org/3/library/os.html#os.getenv
    'api_key': '3b756770793fe4a71bd041d460d9399f10fa1f7e15381d13e25732fd2aba9a86',        # your serpapi api
    'engine': 'google_maps',                # SerpApi search engine	
    'q': 'charge',                          # query
    'll': '@40.7455096,-74.0083012,15.1z',  # GPS coordinates
    'type': 'search',                       # list of results for the query
    'hl': 'en',                             # language
    'start': 0,                             # pagination
}

search = GoogleSearch(params)               # where data extraction happens on the backend
results = search.get_dict()                 # JSON -> Python dict

# %%
local_results_data = []
for result in results['local_results']:
    result_default = defaultdict(lambda : np.NAN, result)
    local_results_data.append((result_default['title'], 
                               result_default['data_id'], 
                                result_default['gps_coordinates'], 
                                result_default['type'], 
                                result_default['address'], 
                                result_default['phone'], 
                                result_default['website'], 
                                result_default['rating'],
                                result_default['reviews'],
     ) )
local_results_data
# Out:
# [('Livingston Charge Port Charging Station',
#   '0x89c259ad57ad2e27:0xa698234369c32d61',
#   {'latitude': 40.756279899999996, 'longitude': -73.99461},
#   'Electric vehicle charging station',
#   '511 9th Ave, New York, NY 10018',
#   '(518) 691-3119',
#   'https://www.solution.energy/',
#   nan,
#   nan),
#  ('Livingston Charge Port Charging Station',
#   '0x89c259bacf48b6db:0x48cf36d8cc6e05a',
#   {'latitude': 40.745399899999995, 'longitude': -73.99542},
#   'Electric vehicle charging station',
#   '252 7th Ave, New York, NY 10001',
#   '(518) 691-3119',
#   'https://www.solution.energy/',
#   4,
#   1),
#  ('Livingston Charge Port Charging Station',
#   '0x89c259a39c014cdb:0x47d68867f5654716',
#   {'latitude': 40.74057, 'longitude': -73.99146999999999},
#   'Electric vehicle charging station',
#   '4 W 21st St, New York, NY 10010',
#   '(518) 691-3119',
#   'https://www.solution.energy/',
#   nan,
#   nan),
#  ('EV Connect Charging Station',
#   '0x89c25853281781b7:0x8950f2224138f711',
#   {'latitude': 40.756891599999996, 'longitude': -73.9917713},
#   'Electric vehicle charging station',
#   '625 8th Ave, New York, NY 10018',
#   '(866) 816-7584',
#   'https://www.evconnect.com/',
#   nan,
#   nan),
#  ('Livingston Charge Port Charging Station',
#   '0x89c259a7d4432941:0x54300ceedc14c163',
#   {'latitude': 40.74538, 'longitude': -73.98571},
#   'Electric vehicle charging station',
#   '10 E 30th St, New York, NY 10016',
#   '(518) 691-3119',
#   'https://www.solution.energy/',
#   nan,
#   nan),
#  ('Livingston Charge Port Charging Station',
#   '0x89c2584c4aaf5f07:0xb694cc8bf8cefc37',
#   {'latitude': 40.76087, 'longitude': -73.9977399},
#   'Electric vehicle charging station',
#   '555 W 42nd St, New York, NY 10036',
#   '(518) 691-3119',
#   'https://www.solution.energy/',
#   nan,
#   nan),
#  ('Blink Charging Station',
#   '0x89c258ff3e4d4d53:0x332ebe03d2650aad',
#   {'latitude': 40.747142499999995, 'longitude': -73.99004529999999},
#   'Electric vehicle charging station',
#   '851 6th Ave, New York, NY 10001',
#   '(888) 998-2546',
#   'https://www.blinkcharging.com/',
#   nan,
#   nan),
#  ('ChargePoint Charging Station',
#   '0x89c259d9fcc5c49b:0x99dbc95bbf837da',
#   {'latitude': 40.750935, 'longitude': -74.024818},
#   'Electric vehicle charging station',
#   '2 12th St, Hoboken, NJ 07030',
#   '(888) 758-4389',
#   'https://www.chargepoint.com/',
#   nan,
#   nan),
#  ('Blink Charging Station',
#   '0x89c2599436e3504f:0xbf503ce00e15b1be',
#   {'latitude': 40.735093899999995, 'longitude': -74.00187},
#   'Electric vehicle charging station',
#   '160 W 10th St, New York, NY 10014',
#   '(888) 998-2546',
#   'https://www.blinkcharging.com/',
#   nan,
#   nan),
#  ('Electric Vehicle Charging Station',
#   '0x89c259b8869ce50b:0x21e950858b3d1b43',
#   {'latitude': 40.745825499999995, 'longitude': -74.0059352},
#   'Electric vehicle charging station',
#   'Parking lot, 161 10th Ave, New York, NY 10011',
#   nan,
#   nan,
#   3,
#   2),
#  ('Livingston Charge Port Charging Station',
#   '0x89c2584e72e25c39:0x8b3f846de61afd3b',
#   {'latitude': 40.7624, 'longitude': -73.99634999999999},
#   'Electric vehicle charging station',
#   '550 W 45th St, New York, NY 10036',
#   '(518) 691-3119',
#   'https://www.solution.energy/',
#   nan,
#   nan),
#  ('Blink Charging Station',
#   '0x89c259a1d0a7273b:0xd338a47ced3229b4',
#   {'latitude': 40.7362174, 'longitude': -73.986665},
#   'Electric vehicle charging station',
#   '130 E 18th St, New York, NY 10003',
#   '(888) 998-2546',
#   'https://blinkcharging.com/',
#   nan,
#   nan),
#  ('ChargePoint Charging Station',
#   '0x89c25990316d8999:0x2100e5dd35a41d01',
#   {'latitude': 40.728283, 'longitude': -73.99725099999999},
#   'Electric vehicle charging station',
#   '2 Washington Square Village, New York, NY 10012',
#   '(888) 758-4389',
#   'https://na.chargepoint.com/charge_point?id=1:10088841&action=VIEW',
#   nan,
#   nan),
#  ('ChargePoint Charging Station',
#   '0x89c259e1cb9540c3:0x5e59177293a0d3ca',
#   {'latitude': 40.739129999999996, 'longitude': -74.028824},
#   'Electric vehicle charging station',
#   '215 Hudson St, Hoboken, NJ 07030',
#   '(888) 758-4389',
#   'https://www.chargepoint.com/',
#   nan,
#   nan),
#  ('Tesla Destination Charger',
#   '0x89c259978b6e9041:0xa74e0b7db727b3f2',
#   {'latitude': 40.7355952, 'longitude': -73.99522189999999},
#   'Electric vehicle charging station',
#   '20 W 13th St, New York, NY 10011',
#   '(800) 836-6666',
#   'https://www.tesla.com/charging',
#   nan,
#   nan),
#  ('Tesla Destination Charger',
#   '0x89c259aedc6d48af:0x9d392675cf107661',
#   {'latitude': 40.748948999999996, 'longitude': -73.9900124},
#   'Electric vehicle charging station',
#   '126 W 32nd St, New York, NY 10001',
#   '(212) 564-2627',
#   'https://www.tesla.com/charging',
#   nan,
#   nan),
#  ('Tesla Destination Charger',
#   '0x89c259a2b75c8ea3:0x297a0a17b1e06226',
#   {'latitude': 40.737635499999996, 'longitude': -73.99392069999999},
#   'Electric vehicle charging station',
#   '16 W 16th St, New York, NY 10011',
#   '(212) 242-9635',
#   'https://www.tesla.com/charging',
#   nan,
#   nan),
#  ('Tesla Destination Charger',
#   '0x89c25997e03f6dc1:0xbe09498adb5cdb02',
#   {'latitude': 40.7372215, 'longitude': -73.996045},
#   'Electric vehicle charging station',
#   '55 W 14th St, New York, NY 10011',
#   '(212) 242-9218',
#   'https://www.tesla.com/charging',
#   nan,
#   nan),
#  ('Blink Charging Station',
#   '0x89c259bee4815f89:0x2211ae2f202c851d',
#   {'latitude': 40.741420999999995, 'longitude': -74.003186},
#   'Electric vehicle charging station',
#   '111 8th Ave, New York, NY 10011',
#   '(888) 998-2546',
#   nan,
#   nan,
#   nan),
#  ('Tesla Destination Charger',
#   '0x89c259987dd89fa1:0x879c9b39d592b313',
#   {'latitude': 40.736292999999996, 'longitude': -73.991939},
#   'Electric vehicle charging station',
#   '21 E 15th St, Manhattan, NY 10003',
#   '(800) 836-6666',
#   'https://www.tesla.com/charging',
#   nan,
#   nan)]

# %%
local_results_data
# Out:
# [('Livingston Charge Port Charging Station',
#   '0x89c259ad57ad2e27:0xa698234369c32d61',
#   {'latitude': 40.756279899999996, 'longitude': -73.99461},
#   'Electric vehicle charging station',
#   '511 9th Ave, New York, NY 10018',
#   '(518) 691-3119',
#   'https://www.solution.energy/'),
#  ('Livingston Charge Port Charging Station',
#   '0x89c259bacf48b6db:0x48cf36d8cc6e05a',
#   {'latitude': 40.745399899999995, 'longitude': -73.99542},
#   'Electric vehicle charging station',
#   '252 7th Ave, New York, NY 10001',
#   '(518) 691-3119',
#   'https://www.solution.energy/'),
#  ('Livingston Charge Port Charging Station',
#   '0x89c259a39c014cdb:0x47d68867f5654716',
#   {'latitude': 40.74057, 'longitude': -73.99146999999999},
#   'Electric vehicle charging station',
#   '4 W 21st St, New York, NY 10010',
#   '(518) 691-3119',
#   'https://www.solution.energy/'),
#  ('EV Connect Charging Station',
#   '0x89c25853281781b7:0x8950f2224138f711',
#   {'latitude': 40.756891599999996, 'longitude': -73.9917713},
#   'Electric vehicle charging station',
#   '625 8th Ave, New York, NY 10018',
#   '(866) 816-7584',
#   'https://www.evconnect.com/'),
#  ('Livingston Charge Port Charging Station',
#   '0x89c259a7d4432941:0x54300ceedc14c163',
#   {'latitude': 40.74538, 'longitude': -73.98571},
#   'Electric vehicle charging station',
#   '10 E 30th St, New York, NY 10016',
#   '(518) 691-3119',
#   'https://www.solution.energy/'),
#  ('Livingston Charge Port Charging Station',
#   '0x89c2584c4aaf5f07:0xb694cc8bf8cefc37',
#   {'latitude': 40.76087, 'longitude': -73.9977399},
#   'Electric vehicle charging station',
#   '555 W 42nd St, New York, NY 10036',
#   '(518) 691-3119',
#   'https://www.solution.energy/'),
#  ('Blink Charging Station',
#   '0x89c258ff3e4d4d53:0x332ebe03d2650aad',
#   {'latitude': 40.747142499999995, 'longitude': -73.99004529999999},
#   'Electric vehicle charging station',
#   '851 6th Ave, New York, NY 10001',
#   '(888) 998-2546',
#   'https://www.blinkcharging.com/'),
#  ('ChargePoint Charging Station',
#   '0x89c259d9fcc5c49b:0x99dbc95bbf837da',
#   {'latitude': 40.750935, 'longitude': -74.024818},
#   'Electric vehicle charging station',
#   '2 12th St, Hoboken, NJ 07030',
#   '(888) 758-4389',
#   'https://www.chargepoint.com/'),
#  ('Blink Charging Station',
#   '0x89c2599436e3504f:0xbf503ce00e15b1be',
#   {'latitude': 40.735093899999995, 'longitude': -74.00187},
#   'Electric vehicle charging station',
#   '160 W 10th St, New York, NY 10014',
#   '(888) 998-2546',
#   'https://www.blinkcharging.com/'),
#  ('Electric Vehicle Charging Station',
#   '0x89c259b8869ce50b:0x21e950858b3d1b43',
#   {'latitude': 40.745825499999995, 'longitude': -74.0059352},
#   'Electric vehicle charging station',
#   'Parking lot, 161 10th Ave, New York, NY 10011',
#   nan,
#   nan),
#  ('Livingston Charge Port Charging Station',
#   '0x89c2584e72e25c39:0x8b3f846de61afd3b',
#   {'latitude': 40.7624, 'longitude': -73.99634999999999},
#   'Electric vehicle charging station',
#   '550 W 45th St, New York, NY 10036',
#   '(518) 691-3119',
#   'https://www.solution.energy/'),
#  ('Blink Charging Station',
#   '0x89c259a1d0a7273b:0xd338a47ced3229b4',
#   {'latitude': 40.7362174, 'longitude': -73.986665},
#   'Electric vehicle charging station',
#   '130 E 18th St, New York, NY 10003',
#   '(888) 998-2546',
#   'https://blinkcharging.com/'),
#  ('ChargePoint Charging Station',
#   '0x89c25990316d8999:0x2100e5dd35a41d01',
#   {'latitude': 40.728283, 'longitude': -73.99725099999999},
#   'Electric vehicle charging station',
#   '2 Washington Square Village, New York, NY 10012',
#   '(888) 758-4389',
#   'https://na.chargepoint.com/charge_point?id=1:10088841&action=VIEW'),
#  ('ChargePoint Charging Station',
#   '0x89c259e1cb9540c3:0x5e59177293a0d3ca',
#   {'latitude': 40.739129999999996, 'longitude': -74.028824},
#   'Electric vehicle charging station',
#   '215 Hudson St, Hoboken, NJ 07030',
#   '(888) 758-4389',
#   'https://www.chargepoint.com/'),
#  ('Tesla Destination Charger',
#   '0x89c259978b6e9041:0xa74e0b7db727b3f2',
#   {'latitude': 40.7355952, 'longitude': -73.99522189999999},
#   'Electric vehicle charging station',
#   '20 W 13th St, New York, NY 10011',
#   '(800) 836-6666',
#   'https://www.tesla.com/charging'),
#  ('Tesla Destination Charger',
#   '0x89c259aedc6d48af:0x9d392675cf107661',
#   {'latitude': 40.748948999999996, 'longitude': -73.9900124},
#   'Electric vehicle charging station',
#   '126 W 32nd St, New York, NY 10001',
#   '(212) 564-2627',
#   'https://www.tesla.com/charging'),
#  ('Tesla Destination Charger',
#   '0x89c259a2b75c8ea3:0x297a0a17b1e06226',
#   {'latitude': 40.737635499999996, 'longitude': -73.99392069999999},
#   'Electric vehicle charging station',
#   '16 W 16th St, New York, NY 10011',
#   '(212) 242-9635',
#   'https://www.tesla.com/charging'),
#  ('Tesla Destination Charger',
#   '0x89c25997e03f6dc1:0xbe09498adb5cdb02',
#   {'latitude': 40.7372215, 'longitude': -73.996045},
#   'Electric vehicle charging station',
#   '55 W 14th St, New York, NY 10011',
#   '(212) 242-9218',
#   'https://www.tesla.com/charging'),
#  ('Blink Charging Station',
#   '0x89c259bee4815f89:0x2211ae2f202c851d',
#   {'latitude': 40.741420999999995, 'longitude': -74.003186},
#   'Electric vehicle charging station',
#   '111 8th Ave, New York, NY 10011',
#   '(888) 998-2546',
#   nan),
#  ('Tesla Destination Charger',
#   '0x89c259987dd89fa1:0x879c9b39d592b313',
#   {'latitude': 40.736292999999996, 'longitude': -73.991939},
#   'Electric vehicle charging station',
#   '21 E 15th St, Manhattan, NY 10003',
#   '(800) 836-6666',
#   'https://www.tesla.com/charging')]
